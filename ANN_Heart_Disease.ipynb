# %% [markdown]
# # ANN Assignment – Heart Disease Prediction
# **Author:** Ishfaque Ahmed
# **Dataset:** Heart Disease Dataset (Kaggle)
# **Framework:** TensorFlow / Keras
# **Task:** Binary Classification

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('/content/heart_disease.csv')
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 0                   No                High       Medium    7.633228
# 1                   No              Medium         High    8.744034
# 2                  Yes                 Low          Low    4.440440
# 3                  Yes                 Low         High    5.249405
# 4                   No                 Low         High    7.030971
#
#    Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0             Medium              342.0                  NaN  12.969246
# 1             Medium              133.0                157.0   9.355389
# 2                Low              393.0                 92.0  12.709873
# 3               High              293.0                 94.0  12.509046
# 4               High              263.0                154.0  10.381259
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                    No
# 1           19.298875                    No
# 2           11.230926                    No
# 3            5.961958                    No
# 4            8.153887                    No
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)

# %%
# Dataset shape and info
print('Shape:', df.shape)
print('-'*50)
df.info()
# Out:
# Shape: (10000, 21)
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
#  14  Sleep Hours           9975 non-null   float64
#  15  Sugar Consumption     9970 non-null   object
#  16  Triglyceride Level    9974 non-null   float64
#  17  Fasting Blood Sugar   9978 non-null   float64
#  18  CRP Level             9974 non-null   float64
#  19  Homocysteine Level    9980 non-null   float64
#  20  Heart Disease Status  10000 non-null  object
# dtypes: float64(9), object(12)
# memory usage: 1.6+ MB

# %%
for col in df.columns:
    print("Column:", col)
    print(df[col].describe())
    print("-" * 40)
# Out:
# Column: Age
# count    9971.000000
# mean       49.296259
# std        18.193970
# min        18.000000
# 25%        34.000000
# 50%        49.000000
# 75%        65.000000
# max        80.000000
# Name: Age, dtype: float64
# ----------------------------------------
# Column: Gender
# count     9981
# unique       2
# top       Male
# freq      5003
# Name: Gender, dtype: object
# ----------------------------------------
# Column: Blood Pressure
# count    9981.000000
# mean      149.757740
# std        17.572969
# min       120.000000
# 25%       134.000000
# 50%       150.000000
# 75%       165.000000
# max       180.000000
# Name: Blood Pressure, dtype: float64
# ----------------------------------------
# Column: Cholesterol Level
# count    9970.000000
# mean      225.425577
# std        43.575809
# min       150.000000
# 25%       187.000000
# 50%       226.000000
# 75%       263.000000
# max       300.000000
# Name: Cholesterol Level, dtype: float64
# ----------------------------------------
# Column: Exercise Habits
# count     9975
# unique       3
# top       High
# freq      3372
# Name: Exercise Habits, dtype: object
# ----------------------------------------
# Column: Smoking
# count     9975
# unique       2
# top        Yes
# freq      5123
# Name: Smoking, dtype: object
# ----------------------------------------
# Column: Family Heart Disease
# count     9979
# unique       2
# top         No
# freq      5004
# Name: Family Heart Disease, dtype: object
# ----------------------------------------
# Column: Diabetes
# count     9970
# unique       2
# top         No
# freq      5018
# Name: Diabetes, dtype: object
# ----------------------------------------
# Column: BMI
# count    9978.000000
# mean       29.077269
# std         6.307098
# min        18.002837
# 25%        23.658075
# 50%        29.079492
# 75%        34.520015
# max        39.996954
# Name: BMI, dtype: float64
# ----------------------------------------
# Column: High Blood Pressure
# count     9974
# unique       2
# top        Yes
# freq      5022
# Name: High Blood Pressure, dtype: object
# ----------------------------------------
# Column: Low HDL Cholesterol
# count     9975
# unique       2
# top        Yes
# freq      5000
# Name: Low HDL Cholesterol, dtype: object
# ----------------------------------------
# Column: High LDL Cholesterol
# count     9974
# unique       2
# top         No
# freq      5036
# Name: High LDL Cholesterol, dtype: object
# ----------------------------------------
# Column: Alcohol Consumption
# count       7414
# unique         3
# top       Medium
# freq        2500
# Name: Alcohol Consumption, dtype: object
# ----------------------------------------
# Column: Stress Level
# count       9978
# unique         3
# top       Medium
# freq        3387
# Name: Stress Level, dtype: object
# ----------------------------------------
# Column: Sleep Hours
# count    9975.000000
# mean        6.991329
# std         1.753195
# min         4.000605
# 25%         5.449866
# 50%         7.003252
# 75%         8.531577
# max         9.999952
# Name: Sleep Hours, dtype: float64
# ----------------------------------------
# Column: Sugar Consumption
# count     9970
# unique       3
# top        Low
# freq      3390
# Name: Sugar Consumption, dtype: object
# ----------------------------------------
# Column: Triglyceride Level
# count    9974.000000
# mean      250.734409
# std        87.067226
# min       100.000000
# 25%       176.000000
# 50%       250.000000
# 75%       326.000000
# max       400.000000
# Name: Triglyceride Level, dtype: float64
# ----------------------------------------
# Column: Fasting Blood Sugar
# count    9978.000000
# mean      120.142213
# std        23.584011
# min        80.000000
# 25%        99.000000
# 50%       120.000000
# 75%       141.000000
# max       160.000000
# Name: Fasting Blood Sugar, dtype: float64
# ----------------------------------------
# Column: CRP Level
# count    9974.000000
# mean        7.472201
# std         4.340248
# min         0.003647
# 25%         3.674126
# 50%         7.472164
# 75%        11.255592
# max        14.997087
# Name: CRP Level, dtype: float64
# ----------------------------------------
# Column: Homocysteine Level
# count    9980.000000
# mean       12.456271
# std         4.323426
# min         5.000236
# 25%         8.723334
# 50%        12.409395
# 75%        16.140564
# max        19.999037
# Name: Homocysteine Level, dtype: float64
# ----------------------------------------
# Column: Heart Disease Status
# count     10000
# unique        2
# top          No
# freq       8000
# Name: Heart Disease Status, dtype: object
# ----------------------------------------

# %%
# Missing values
print('Missing values per column:')
print(df.isnull().sum())
# Out:
# Missing values per column:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
# Target distribution
df['Heart Disease Status'].value_counts().plot(kind='bar', color=['steelblue', 'tomato'])
plt.title('Heart Disease Status Distribution')
plt.xlabel('Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Distribution of numerical features
num_cols = ['Age', 'Blood Pressure', 'Cholesterol Level', 'BMI',
            'Triglyceride Level', 'Fasting Blood Sugar', 'CRP Level', 'Homocysteine Level']

df[num_cols].hist(figsize=(14, 8), bins=20, edgecolor='black')
plt.suptitle('Feature Distributions', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap (numerical only)
plt.figure(figsize=(10, 7))
sns.heatmap(df[num_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Data Preprocessing

# %%
# Fill missing values
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].fillna(df[col].mode()[0])
    else:
        df[col] = df[col].fillna(df[col].mean())

print('Missing values after fill:', df.isnull().sum().sum())
# Out:
# Missing values after fill: 0

# %%
# Encode categorical columns
le = LabelEncoder()
cat_cols = df.select_dtypes(include='object').columns.tolist()

for col in cat_cols:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level  Exercise Habits  Smoking  \
# 0  56.0       1           153.0              155.0                0        1
# 1  69.0       0           146.0              286.0                0        0
# 2  46.0       1           126.0              216.0                1        0
# 3  32.0       0           122.0              293.0                0        1
# 4  60.0       1           166.0              242.0                1        1
#
#    Family Heart Disease  Diabetes        BMI  High Blood Pressure  ...  \
# 0                     1         0  24.991591                    1  ...
# 1                     1         1  25.221799                    0  ...
# 2                     0         0  29.855447                    0  ...
# 3                     1         0  24.130477                    1  ...
# 4                     1         1  20.486289                    1  ...
#
#    High LDL Cholesterol  Alcohol Consumption  Stress Level  Sleep Hours  \
# 0                     0                    0             2     7.633228
# 1                     0                    2             0     8.744034
# 2                     1                    1             1     4.440440
# 3                     1                    1             0     5.249405
# 4                     0                    1             0     7.030971
#
#    Sugar Consumption  Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0                  2               342.0           120.142213  12.969246
# 1                  2               133.0           157.000000   9.355389
# 2                  1               393.0            92.000000  12.709873
# 3                  0               293.0            94.000000  12.509046
# 4                  0               263.0           154.000000  10.381259
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                     0
# 1           19.298875                     0
# 2           11.230926                     0
# 3            5.961958                     0
# 4            8.153887                     0
#
# [5 rows x 21 columns]

# %%
# Separate features and target
X = df.drop('Heart Disease Status', axis=1)
y = df['Heart Disease Status']

print('X shape:', X.shape)
print('y shape:', y.shape)
# Out:
# X shape: (10000, 20)
# y shape: (10000,)

# %%
# Train-test split (80/20)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

print('Train size:', X_train.shape[0])
print('Test size:', X_test.shape[0])
# Out:
# Train size: 8000
# Test size: 2000

# %%
# Normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## 5. Build ANN Model

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')   # binary classification
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,457 (13.50 KB)
#  Trainable params: 3,457 (13.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 6. Train the Model

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7942 - loss: 0.5280 - val_accuracy: 0.8163 - val_loss: 0.4848
# Epoch 2/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7982 - loss: 0.5119 - val_accuracy: 0.8163 - val_loss: 0.4855
# Epoch 3/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7982 - loss: 0.5135 - val_accuracy: 0.8163 - val_loss: 0.4827
# Epoch 4/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.5115 - val_accuracy: 0.8163 - val_loss: 0.4844
# Epoch 5/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.5083 - val_accuracy: 0.8163 - val_loss: 0.4850
# Epoch 6/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.5033 - val_accuracy: 0.8163 - val_loss: 0.4829
# Epoch 7/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.5044 - val_accuracy: 0.8163 - val_loss: 0.4849
# Epoch 8/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.5029 - val_accuracy: 0.8163 - val_loss: 0.4908
# Epoch 9/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4980 - val_accuracy: 0.8163 - val_loss: 0.4862
# Epoch 10/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.5011 - val_accuracy: 0.8163 - val_loss: 0.4859
# Epoch 11/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4967 - val_accuracy: 0.8163 - val_loss: 0.4817
# Epoch 12/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4979 - val_accuracy: 0.8163 - val_loss: 0.4855
# Epoch 13/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4978 - val_accuracy: 0.8163 - val_loss: 0.4873
# Epoch 14/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4954 - val_accuracy: 0.8163 - val_loss: 0.4877
# Epoch 15/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4931 - val_accuracy: 0.8163 - val_loss: 0.4880
# Epoch 16/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4937 - val_accuracy: 0.8163 - val_loss: 0.4894
# Epoch 17/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4937 - val_accuracy: 0.8163 - val_loss: 0.4877
# Epoch 18/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7981 - loss: 0.4921 - val_accuracy: 0.8163 - val_loss: 0.4870
# Epoch 19/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7976 - loss: 0.4896 - val_accuracy: 0.8163 - val_loss: 0.4865
# Epoch 20/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7982 - loss: 0.4907 - val_accuracy: 0.8163 - val_loss: 0.4881
# Epoch 21/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7981 - loss: 0.4918 - val_accuracy: 0.8163 - val_loss: 0.4856
# Epoch 22/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7985 - loss: 0.4898 - val_accuracy: 0.8163 - val_loss: 0.4861
# Epoch 23/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7981 - loss: 0.4873 - val_accuracy: 0.8163 - val_loss: 0.4882
# Epoch 24/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7987 - loss: 0.4878 - val_accuracy: 0.8163 - val_loss: 0.4878
# Epoch 25/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7981 - loss: 0.4874 - val_accuracy: 0.8163 - val_loss: 0.4873
# Epoch 26/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7986 - loss: 0.4850 - val_accuracy: 0.8163 - val_loss: 0.4887
# Epoch 27/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7987 - loss: 0.4876 - val_accuracy: 0.8163 - val_loss: 0.4916
# Epoch 28/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7987 - loss: 0.4833 - val_accuracy: 0.8163 - val_loss: 0.4890
# Epoch 29/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7985 - loss: 0.4859 - val_accuracy: 0.8163 - val_loss: 0.4888
# Epoch 30/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7997 - loss: 0.4788 - val_accuracy: 0.8175 - val_loss: 0.4917
# Epoch 31/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7976 - loss: 0.4827 - val_accuracy: 0.8163 - val_loss: 0.4920
# Epoch 32/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7987 - loss: 0.4809 - val_accuracy: 0.8163 - val_loss: 0.4893
# Epoch 33/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7989 - loss: 0.4808 - val_accuracy: 0.8163 - val_loss: 0.4906
# Epoch 34/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7989 - loss: 0.4806 - val_accuracy: 0.8175 - val_loss: 0.4945
# Epoch 35/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7997 - loss: 0.4814 - val_accuracy: 0.8163 - val_loss: 0.4914
# Epoch 36/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7987 - loss: 0.4768 - val_accuracy: 0.8163 - val_loss: 0.4924
# Epoch 37/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7989 - loss: 0.4771 - val_accuracy: 0.8163 - val_loss: 0.4921
# Epoch 38/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7990 - loss: 0.4767 - val_accuracy: 0.8150 - val_loss: 0.4921
# Epoch 39/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8001 - loss: 0.4747 - val_accuracy: 0.8150 - val_loss: 0.4914
# Epoch 40/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8000 - loss: 0.4751 - val_accuracy: 0.8150 - val_loss: 0.4927
# Epoch 41/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7996 - loss: 0.4730 - val_accuracy: 0.8163 - val_loss: 0.4941
# Epoch 42/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8008 - loss: 0.4769 - val_accuracy: 0.8163 - val_loss: 0.4943
# Epoch 43/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8000 - loss: 0.4733 - val_accuracy: 0.8175 - val_loss: 0.4942
# Epoch 44/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7990 - loss: 0.4714 - val_accuracy: 0.8163 - val_loss: 0.4969
# Epoch 45/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8001 - loss: 0.4711 - val_accuracy: 0.8175 - val_loss: 0.4960
# Epoch 46/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7999 - loss: 0.4716 - val_accuracy: 0.8175 - val_loss: 0.4989
# Epoch 47/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8011 - loss: 0.4711 - val_accuracy: 0.8150 - val_loss: 0.5001
# Epoch 48/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7994 - loss: 0.4738 - val_accuracy: 0.8150 - val_loss: 0.4996
# Epoch 49/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7999 - loss: 0.4691 - val_accuracy: 0.8150 - val_loss: 0.4984
# Epoch 50/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8018 - loss: 0.4653 - val_accuracy: 0.8138 - val_loss: 0.5007

# %%
# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['accuracy'], label='Train Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
axes[0].set_title('Accuracy over Epochs')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True)

axes[1].plot(history.history['loss'], label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Val Loss')
axes[1].set_title('Loss over Epochs')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Model Evaluation

# %%
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

print('Accuracy:', accuracy_score(y_test, y_pred))
print()
print(classification_report(y_test, y_pred, target_names=['No Disease', 'Disease']))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.7995
#
#               precision    recall  f1-score   support
#
#   No Disease       0.80      1.00      0.89      1600
#      Disease       0.40      0.01      0.01       400
#
#     accuracy                           0.80      2000
#    macro avg       0.60      0.50      0.45      2000
# weighted avg       0.72      0.80      0.71      2000

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['No Disease', 'Disease'],
            yticklabels=['No Disease', 'Disease'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()
